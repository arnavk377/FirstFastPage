# %% [markdown]
# # Javascript Trial
# > Testing out Javascript
#
# - toc: false
# - badges: true
# - comments: true
# - categories: [csp, js, week5]

# %% [markdown]
# # Javascript
#
# Javascript is different from Python.

# %%
console.log("Hello World");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/poonam/vscode/FirstFastPage-1/_notebooks/2022-09-23-js-page.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/poonam/vscode/FirstFastPage-1/_notebooks/2022-09-23-js-page.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> console.log("Hello World")
#
# NameError: name 'console' is not defined
